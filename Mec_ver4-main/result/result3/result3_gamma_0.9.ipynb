# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd
plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
plt.tight_layout()

# %%
a = 0
b = 100
folder_name1 = "DQN5" + '/'
folder_name2 = "DDQN5" + '/'
folder_name3 = "DuelingDQN3" + '/'
folder_name4 = "DoubleDuelingDQN1" + '/'
folder_name5 = "DQN5_no_energy" + '/'
folder_name6 = "DDQN5_no_energy" + '/'
folder_name7 = "DuelingDQN3_no_energy" + '/'
folder_name8 = "DQN2" + '/'
folder_nameR0 = "Random_0_1_1_1_1_1" + '/'
folder_nameR1 = "Random_1_1_1_1_1_1" + '/'
folder_nameR2 = "Random_2_1_1_1_1_1" + '/'
folder_nameR3 = "Random_3_1_1_1_1_1" + '/'
folder_nameR4 = "Random_4_1_1_1_1_1" + '/'
folder_nameR5 = "Random_5_1_1_1_1_1" + '/'

# %%
metric_file = "drop_task.csv"

data_delay = pd.read_csv(folder_name1 + metric_file).values[a:b]
number = [i + a + 1 for i in range(data_delay.shape[0])]
plt.plot(number, data_delay, color="red", label = "DQN")
data_delay = pd.read_csv(folder_name2 + metric_file).values[a:b]
plt.plot(number, data_delay, color="blue", label = "Double DQN")
data_delay = pd.read_csv(folder_name3 + metric_file).values[a:b]
plt.plot(number, data_delay, color="green", label = "Dueling DQN")

line = '--'
data_delay = pd.read_csv(folder_name5 + metric_file).values[a:b]
plt.plot(number, data_delay, color="red", label = "DQN no energy", linestyle = line)
data_delay = pd.read_csv(folder_name6 + metric_file).values[a:b]
plt.plot(number, data_delay, color="blue", label = "Double DQN no energy", linestyle = line)
data_delay = pd.read_csv(folder_name7 + metric_file).values[a:b]
plt.plot(number, data_delay, color="green", label = "Dueling DQN no energy", linestyle = line)

plt.legend()
plt.ylim([-0.05, 1])
plt.grid(linestyle = '--', linewidth = 0.5)
plt.ylabel("percentage of overdue tasks")
plt.savefig("../../pics/scenario_1/drop_task.pdf")
plt.show()
plt.clf()

# %%
d = -10
metric_file = "drop_task.csv"
print(pd.read_csv(folder_name1 + metric_file).values[d:].mean()*100)
print(pd.read_csv(folder_name2 + metric_file).values[d:].mean()*100)
print(pd.read_csv(folder_name3 + metric_file).values[d:].mean()*100)
print(pd.read_csv(folder_name5 + metric_file).values[d:].mean()*100)
print(pd.read_csv(folder_name6 + metric_file).values[d:].mean()*100)
print(pd.read_csv(folder_name7 + metric_file).values[d:].mean()*100)
print()
metric_file = "energy.csv"
print(pd.read_csv(folder_name1 + metric_file).values[d:].mean())
print(pd.read_csv(folder_name2 + metric_file).values[d:].mean())
print(pd.read_csv(folder_name3 + metric_file).values[d:].mean())
print(pd.read_csv(folder_name5 + metric_file).values[d:].mean())
print(pd.read_csv(folder_name6 + metric_file).values[d:].mean())
print(pd.read_csv(folder_name7 + metric_file).values[d:].mean())
# Out:
# 0.48000000000000004
# 0.65
# 0.5499999999999999
# 0.56
# 0.62
# 0.42000000000000004
#
# 1.3441419
# 1.2652478999999999
# 1.2455639999999994
# 2.171799900000001
# 2.5664021999999997
# 2.0644272

# %%
metric_file = "energy.csv"

data_delay = pd.read_csv(folder_name1 + metric_file).values[a:b]
number = [i + a + 1 for i in range(data_delay.shape[0])]
plt.plot(number, data_delay, color="red", label = "DQN")
data_delay = pd.read_csv(folder_name2 + metric_file).values[a:b]
plt.plot(number, data_delay, color="blue", label = "Double DQN")
data_delay = pd.read_csv(folder_name3 + metric_file).values[a:b]
plt.plot(number, data_delay, color="green", label = "Dueling DQN")

line = '--'
data_delay = pd.read_csv(folder_name5 + metric_file).values[a:b]
plt.plot(number, data_delay, color="red", label = "DQN no energy", linestyle = line)
data_delay = pd.read_csv(folder_name6 + metric_file).values[a:b]
plt.plot(number, data_delay, color="blue", label = "Double DQN no energy", linestyle = line)
data_delay = pd.read_csv(folder_name7 + metric_file).values[a:b]
plt.plot(number, data_delay, color="green", label = "Dueling DQN no energy", linestyle = line)

plt.legend()
plt.ylim([-0.05, 3.5])
plt.grid(linestyle = '--', linewidth = 0.5)
plt.ylabel("joule/task")
plt.savefig("../../pics/scenario_1/energy.pdf")
plt.show()
plt.clf()

# %%
metric_file = "drop_task.csv"

data_delay = pd.read_csv(folder_nameR1 + metric_file).values[a:b]
number = [i + a + 1 for i in range(data_delay.shape[0])]
plt.plot(number, data_delay, color="red", label = "Random1")
data_delay = pd.read_csv(folder_nameR2 + metric_file).values[a:b]
plt.plot(number, data_delay, color="orange", label = "Random2")
data_delay = pd.read_csv(folder_nameR3 + metric_file).values[a:b]
plt.plot(number, data_delay, color="blue", label = "Random3")
data_delay = pd.read_csv(folder_nameR4 + metric_file).values[a:b]
plt.plot(number, data_delay, color="purple", label = "Random4")
data_delay = pd.read_csv(folder_nameR5 + metric_file).values[a:b]
plt.plot(number, data_delay, color="pink", label = "Random5")

line = '-'
# data_delay = pd.read_csv(folder_name2 + metric_file).values[a:b]
# plt.plot(number, data_delay, color="cyan", label = "Double DQN", linestyle = line)
data_delay = pd.read_csv(folder_name1 + metric_file).values[a:b]
plt.plot(number, data_delay, color="green", label = "DQN", linestyle = line)

plt.legend()
plt.ylim([-0.05, 1])
plt.grid(linestyle = '--', linewidth = 0.5)
plt.ylabel("percentage of overdue tasks")
plt.savefig("../../pics/scenario_2/drop_task.pdf")
plt.show()
plt.clf()

# %%
metric_file = "energy.csv"

data_delay = pd.read_csv(folder_nameR1 + metric_file).values[a:b]
number = [i + a + 1 for i in range(data_delay.shape[0])]
plt.plot(number, data_delay, color="red", label = "Random1")
data_delay = pd.read_csv(folder_nameR2 + metric_file).values[a:b]
plt.plot(number, data_delay, color="orange", label = "Random2")
data_delay = pd.read_csv(folder_nameR3 + metric_file).values[a:b]
plt.plot(number, data_delay, color="blue", label = "Random3")
data_delay = pd.read_csv(folder_nameR4 + metric_file).values[a:b]
plt.plot(number, data_delay, color="purple", label = "Random4")
data_delay = pd.read_csv(folder_nameR5 + metric_file).values[a:b]
plt.plot(number, data_delay, color="pink", label = "Random5")

line = '-'
# data_delay = pd.read_csv(folder_name2 + metric_file).values[a:b]
# plt.plot(number, data_delay, color="cyan", label = "Double DQN", linestyle = line)
data_delay = pd.read_csv(folder_name1 + metric_file).values[a:b]
plt.plot(number, data_delay, color="green", label = "DQN", linestyle = line)

plt.legend()
plt.ylim([-0.05, 4])
plt.grid(linestyle = '--', linewidth = 0.5)
plt.ylabel("joule/task")
plt.savefig("../../pics/scenario_2/energy.pdf")
plt.show()
plt.clf()

# %%
import matplotlib.pyplot as plt
plt.clf()
colors = ["crimson", "purple", "gold"]
f = lambda m,c: plt.plot([],[],marker=m, color=c, ls="none")[0]
handles = [f("s", colors[i]) for i in range(3)]
labels = colors
legend = plt.legend(handles, labels, loc=3, framealpha=1, frameon=False)

def export_legend(legend, filename="legend.png"):
    fig  = legend.figure
    fig.canvas.draw()
    bbox  = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    fig.savefig(filename, dpi="figure", bbox_inches=bbox)

export_legend(legend)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
import pandas as pd

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

def allocation_statistics(folder_name):
    Cov = pd.read_csv(folder_name + "server_allocation.csv", sep=',')
    Cov.columns = ["BS", "VS1", "VS2", "VS3", "VS4", "VS5"]
    #Cov.rename(columns={"server": "a", "bus1": "b", "bus2": "c", "bus3": "d", "bus4": "e", "bus5":"f"})
    columns_titles = ["BS", "VS1", "VS2", "VS3", "VS4", "VS5"]
    df = Cov.divide(Cov.sum(axis=1), axis=0)
    df = df.reindex(columns=columns_titles)    
    df.plot.area(legend = 'reverse')
    plt.savefig("../../pics/scenario_1/"+ folder_name[:-1] +".pdf")

# %%
allocation_statistics(folder_name1)
allocation_statistics(folder_name2)
allocation_statistics(folder_name3)
allocation_statistics(folder_name5)
allocation_statistics(folder_name6)
allocation_statistics(folder_name7)

# %%
folder_VS1 = "DuelingDQN1_1VS" + '/'
folder_VS2 = "DDQN2_3VS" + '/'
folder_VS3 = "DQN5" + '/'
folder_VS4 = "DDQN2_7VS" + '/'
folder_VS5 = "DDQN1_no_energy_1VS" + '/'
folder_VS6 = "DuelingDQN2_no_energy_3VS" + '/'
folder_VS7 = "DuelingDQN3_no_energy" + '/'
folder_VS8 = "DDQN1_no_energy_7VS" + '/'

# %%
c = 90

# %%
metric_file = "drop_task.csv"
performance = list()
performance_no_energy = list()
data_delay1 = pd.read_csv(folder_VS1 + metric_file).values[a:b]
performance.append(100 - data_delay1[c:].mean() * 100)
data_delay2 = pd.read_csv(folder_VS2 + metric_file).values[a:b]
performance.append(100 - data_delay2[c:].mean() * 100)
data_delay3 = pd.read_csv(folder_VS3 + metric_file).values[a:b]
performance.append(100 - data_delay3[c:].mean() * 100)
data_delay4 = pd.read_csv(folder_VS4 + metric_file).values[a:b]
performance.append(100 - data_delay4[c:].mean() * 100)
data_delay5 = pd.read_csv(folder_VS5 + metric_file).values[a:b]
performance_no_energy.append(100 - data_delay5[c:].mean() * 100)
data_delay6 = pd.read_csv(folder_VS6 + metric_file).values[a:b]
performance_no_energy.append(100 - data_delay6[c:].mean() * 100)
data_delay7 = pd.read_csv(folder_VS7 + metric_file).values[a:b]
performance_no_energy.append(100 - data_delay7[c:].mean() * 100)
data_delay8 = pd.read_csv(folder_VS8 + metric_file).values[a:b]
performance_no_energy.append(100 - data_delay8[c:].mean() * 100)

objects = ('1 VS', '3 VS', '5 VS', '7 VS')
y_pos = np.arange(len(objects))

#plt.rcParams['font.size'] = '11'
for index, value in enumerate(performance):
    plt.text(index-0.29, value + 1, str("{:.2f}".format(value)), fontsize=1)
for index, value in enumerate(performance_no_energy):
    plt.text(index+0.11, value + 1, str("{:.2f}".format(value)), fontsize=12)
#plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.bar(y_pos - 0.2, performance, 0.4, label = 'Energy concerned')
plt.bar(y_pos + 0.2, performance_no_energy, 0.4, label = 'Non-energy concerned')
plt.xticks(y_pos, objects)
plt.ylabel('percentage of due tasks(%)')
plt.legend()
#plt.savefig("../../pics/scenario_3/drop_task.pdf")
plt.show()

# %%
metric_file = "energy.csv"
performance = list()
performance_no_energy = list()
data_delay = pd.read_csv(folder_VS1 + metric_file).values[a:b]
performance.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS2 + metric_file).values[a:b]
performance.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS3 + metric_file).values[a:b]
performance.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS4 + metric_file).values[a:b]
performance.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS5 + metric_file).values[a:b]
performance_no_energy.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS6 + metric_file).values[a:b]
performance_no_energy.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS7 + metric_file).values[a:b]
performance_no_energy.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS8 + metric_file).values[a:b]
performance_no_energy.append(data_delay[c:].mean())

objects = ('1 VS', '3 VS', '5 VS', '7 VS')
y_pos = np.arange(len(objects))

#plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.bar(y_pos - 0.2, performance, 0.4, label = 'Energy concerned')
plt.bar(y_pos + 0.2, performance_no_energy, 0.4, label = 'Non-energy concerned')
plt.xticks(y_pos, objects)
plt.ylabel('percentage of overdue tasks (%)')
plt.legend()
plt.savefig("../../pics/scenario_3/energy.pdf")
plt.show()

# %%
metric_file = "delay.csv"
performance = list()
performance_no_energy = list()
# data_delay = pd.read_csv(folder_VS1 + metric_file).values[a:b]
# performance.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS2 + metric_file).values[a:b]
performance.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS3 + metric_file).values[a:b]
performance.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS4 + metric_file).values[a:b]
performance.append(data_delay[c:].mean())
# data_delay = pd.read_csv(folder_VS5 + metric_file).values[a:b]
# performance_no_energy.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS6 + metric_file).values[a:b]
performance_no_energy.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS7 + metric_file).values[a:b]
performance_no_energy.append(data_delay[c:].mean())
data_delay = pd.read_csv(folder_VS8 + metric_file).values[a:b]
performance_no_energy.append(data_delay[c:].mean())

objects = ('3 VS', '5 VS', '7 VS')
y_pos = np.arange(len(objects))

#plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.bar(y_pos - 0.2, performance, 0.4, label = 'Energy concerned')
plt.bar(y_pos + 0.2, performance_no_energy, 0.4, label = 'Non-energy concerned')
plt.xticks(y_pos, objects)
plt.ylabel('percentage of overdue tasks')
plt.legend()
plt.savefig("../../pics/scenario_3/delay.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15860/2478611390.py in <module>
#      28 plt.ylabel('percentage of overdue tasks')
#      29 plt.legend()
# ---> 30 plt.savefig("../../pics/scenario_3/delay.pdf")
#      31 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3013                 patch.set_edgecolor('none')
#    3014
# -> 3015         self.canvas.print_figure(fname, **kwargs)
#    3016
#    3017         if transparent:
#
# ...

# %%
pd.read_csv(folder_VS1 + metric_file).values[80:b, 0]
# Out:
# array([5745.43191266, 5886.01573541, 5984.02088228, 6071.78825726,
#        6154.41657058, 6274.68185364, 6313.75237664, 6340.26165553,
#        6371.42317039, 6452.33939984, 6483.4438201 , 6512.6649205 ,
#        6583.24785248, 6661.84546924, 6692.84011689, 6730.97918516,
#        6769.3325895 , 6804.51838299, 7041.73651611, 7129.56945661])

# %%
import matplotlib.pyplot as plt
x = ["A", "B", "C", "D"]
y = [1, 2, 3, 4]
plt.bar(x, y)
  
for index, value in enumerate(y):
    plt.text(value, index,
             str(value))
  
plt.show()
